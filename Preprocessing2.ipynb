# %% [markdown]
# # Preprocessing 2 works on the sparse matrix created in Preprocesing 1

# %%
import numpy as np
import pandas as pd
import os 
import sys

# %%
# load the sparse matrix
import scipy.sparse
sparse_matrix = scipy.sparse.load_npz('sparse_mat.npz')

# %%
reduced_words = pd.read_csv('reduced_words.csv')

# %%
reduced_words
# Out:
#         Unnamed: 0      id                                              title  \
# 0                0   17283  House Republicans Fret About Winning Their Hea...
# 1                1   17284  Rift Between Officers and Residents as Killing...
# 2                2   17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3                3   17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4                4   17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...            ...     ...                                                ...
# 142565      142565  218078  An eavesdropping Uber driver saved his 16-year...
# 142566      142566  218079  Plane carrying six people returning from a Cav...
# 142567      142567  218080  After helping a fraction of homeowners expecte...
# 142568      142568  218081  Yes, this is real: Michigan just banned bannin...
# 142569      142569  218082  What happened in Washington state after voters...
#
# ...
